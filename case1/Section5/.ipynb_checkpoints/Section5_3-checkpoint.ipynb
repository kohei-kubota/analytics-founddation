# %% [markdown]
# # PART3 特徴量を作ってみよう

# %% [markdown]
# ## おまじない

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.linear_model import LinearRegression as LR

# %% [markdown]
# ## データの読み込み
# - train.csvとtest.csvとsample.csvの３つのファイルを読み込みましょう
# - それぞれを読み込んだものは変数はtrain, test, sampleに代入しましょう
# - sampleを読み込む時は、header=Noneというオプションを忘れないようにしましょう

# %%
train = pd.read_csv("../train.csv")
test = pd.read_csv("../test.csv")
sample = pd.read_csv("../sample.csv", header=None)

# %% [markdown]
# ## yの折れ線グラフを描いてみましょう

# %%
train["y"].plot(figsize=(12,4))

# %% [markdown]
# ## trainの先頭行を表示してみよう

# %%
train.head()
# Out:
#      datetime    y week  soldout        name  kcal remarks event  payday  \
# 0  2013-11-18   90    月        0    厚切りイカフライ   NaN     NaN   NaN     NaN
# 1  2013-11-19  101    火        1     手作りヒレカツ   NaN     NaN   NaN     NaN
# 2  2013-11-20  118    水        0  白身魚唐揚げ野菜あん   NaN     NaN   NaN     NaN
# 3  2013-11-21  120    木        1      若鶏ピリ辛焼   NaN     NaN   NaN     NaN
# 4  2013-11-22  130    金        1    ビッグメンチカツ   NaN     NaN   NaN     NaN
#
#   weather precipitation  temperature
# 0      快晴            --         19.8
# 1      快晴            --         17.0
# 2      快晴            --         15.5
# 3      快晴            --         15.2
# 4      快晴            --         16.1

# %% [markdown]
# ## trainのdatetimeから年と月のデータを取り出し、trainの新たなカラムとして追加しましょう
# - apply関数とsplit関数を使います
# - 年の新しいカラム名はyearとし、月の新しいカラム名はmonthとしましょう

# %%
train["year"] = train["datetime"].apply(lambda x : x.split("-")[0])
train["month"] = train["datetime"].apply(lambda x : x.split("-")[1])

# %% [markdown]
# ## trainの中身を確認してみましょう

# %%
train.head()
# Out:
#      datetime    y week  soldout        name  kcal remarks event  payday  \
# 0  2013-11-18   90    月        0    厚切りイカフライ   NaN     NaN   NaN     NaN
# 1  2013-11-19  101    火        1     手作りヒレカツ   NaN     NaN   NaN     NaN
# 2  2013-11-20  118    水        0  白身魚唐揚げ野菜あん   NaN     NaN   NaN     NaN
# 3  2013-11-21  120    木        1      若鶏ピリ辛焼   NaN     NaN   NaN     NaN
# 4  2013-11-22  130    金        1    ビッグメンチカツ   NaN     NaN   NaN     NaN
#
#   weather precipitation  temperature  year month
# 0      快晴            --         19.8  2013    11
# 1      快晴            --         17.0  2013    11
# 2      快晴            --         15.5  2013    11
# 3      快晴            --         15.2  2013    11
# 4      快晴            --         16.1  2013    11

# %% [markdown]
# ## 同様にtestもdatetimeから年と月のデータを取り出し、testの新たなカラムとして追加しましょう

# %%
test["year"] = test["datetime"].apply(lambda x : x.split("-")[0])
test["month"] = test["datetime"].apply(lambda x : x.split("-")[1])

# %% [markdown]
# ## trainのデータの型を確認してみましょう

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 207 entries, 0 to 206
# Data columns (total 14 columns):
# datetime         207 non-null object
# y                207 non-null int64
# week             207 non-null object
# soldout          207 non-null int64
# name             207 non-null object
# kcal             166 non-null float64
# remarks          21 non-null object
# event            14 non-null object
# payday           10 non-null float64
# weather          207 non-null object
# precipitation    207 non-null object
# temperature      207 non-null float64
# year             207 non-null object
# month            207 non-null object
# dtypes: float64(3), int64(2), object(9)
# memory usage: 22.7+ KB

# %% [markdown]
# ## train,testのデータの型を整数（int）に変換しましょう
# - データの型を変換したい場合は、astype関数を使います
# - オプションにはデータの型を入れます。今回は整数に変換したい為、np.intと書きます
# - 変換したものは、もとのカラムに代入しなおしましょう

# %%
train["year"] = train["year"].astype(np.int)
train["month"] = train["month"].astype(np.int)
test["year"] = test["year"].astype(np.int)
test["month"] = test["month"].astype(np.int)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 207 entries, 0 to 206
# Data columns (total 14 columns):
# datetime         207 non-null object
# y                207 non-null int64
# week             207 non-null object
# soldout          207 non-null int64
# name             207 non-null object
# kcal             166 non-null float64
# remarks          21 non-null object
# event            14 non-null object
# payday           10 non-null float64
# weather          207 non-null object
# precipitation    207 non-null object
# temperature      207 non-null float64
# year             207 non-null int64
# month            207 non-null int64
# dtypes: float64(3), int64(4), object(7)
# memory usage: 22.7+ KB

# %% [markdown]
# ## train,testからyearとmonthを取り出し、変数trainX,testXに代入しましょう

# %%
trainX = train[["year", "month"]]
testX = test[["year", "month"]]

# %% [markdown]
# ## trainXの中身を確認してみましょう

# %%
trainX.head()
# Out:
#    year  month
# 0  2013     11
# 1  2013     11
# 2  2013     11
# 3  2013     11
# 4  2013     11

# %% [markdown]
# ## trainからyを取り出し、変数yに代入しましょう

# %%
y = train["y"]

# %% [markdown]
# ## 回帰モデルの箱を用意しましょう
# - 変数名はmodel1としましょう

# %%
model1 = LR()

# %% [markdown]
# ## 重回帰モデルを作りましょう

# %%
model1.fit(trainX, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %% [markdown]
# ## 作ったモデルの傾きや切片を確かめてみましょう

# %%
model1.coef_
# Out:
# array([-104.0107109 ,   -7.41004428])

# %%
model1.intercept_
# Out:
# 209594.15656370911

# %% [markdown]
# ## testXを使って予測をし、予測結果を変数predに代入しましょう

# %%
pred = model1.predict(testX)

# %% [markdown]
# ## sample[1]に予測結果を代入しましょう

# %%
sample[1] = pred

# %% [markdown]
# ## sampleを"submit4.csv"というファイルで出力して、DeepAnalyticsに投稿しましょう

# %%
sample.to_csv("submit4.csv", index=None, header=None)

# %% [markdown]
# ## 追加する特徴量検討の為に、trainXに対する予測値を変数predに代入しましょう
# - trainXに対して予測を行えば、実際の売り上げyがわかっているので、その差を比較することができます
# - そこでtrainXに対する予測値と、実際の売り上げyとを引き算することで、どの日が大きく予測を外していたかを確認します
# - 大きく外れていたものから共通する要素が見つけられれば、その要素を加えることで更に精度が良いモデルを作れる可能性があります
# - その準備として、まずmodel1とtrainXを使って、trainXに対する予測値を求めましょう

# %%
pred = model1.predict(trainX)

# %% [markdown]
# ## predをtrainの新たなカラムpredとして代入しましょう

# %%
train["pred"] = pred

# %% [markdown]
# ## trainのyとpredを引き算した結果をtrainの新たなカラムresとして代入しましょう
# - yとpredを引き算する為には、単純にtrain["y"] - train["pred"]と書きます

# %%
train["res"] = train["y"] - train["pred"]

# %% [markdown]
# ## trainのresでソートして中身を確認しましょう
# - 今回はhead関数を使わず、表示しましょう

# %%
train.sort_values(by="res")
# Out:
#        datetime    y week  soldout            name   kcal       remarks  \
# 27   2013-12-26   80    木        0              酢豚    NaN           NaN
# 0    2013-11-18   90    月        0        厚切りイカフライ    NaN           NaN
# 81    2014-3-26   51    水        0     肉団子クリームシチュー  392.0           NaN
# 82    2014-3-27   55    木        1        ロース甘味噌焼き  315.0           NaN
# 1    2013-11-19  101    火        1         手作りヒレカツ    NaN           NaN
# 104   2014-4-28   54    月        0        タンドリーチキン  342.0           NaN
# 64    2014-2-28   69    金        0         手作りひれかつ  428.0           NaN
# 107    2014-5-2   47    金        0           鶏の天ぷら  420.0           NaN
# 102   2014-4-24   56    木        1        鶏の照り焼きマヨ  360.0           NaN
# 98    2014-4-18   56    金        1        鶏の味噌漬け焼き  325.0           NaN
# 96    2014-4-16   57    水        0    カレイ唐揚げ野菜あんかけ  330.0           NaN
# 97    2014-4-17   57    木        0            牛丼風煮  333.0           NaN
# 72    2014-3-12   68    水        0          ビーフカレー  370.0           NaN
# 119   2014-5-22   54    木        1  サーモンのムニエル2色ソース  428.0  料理長のこだわりメニュー
# 128    2014-6-4   47    水        0     たっぷりベーコンフライ  424.0           NaN
# 74    2014-3-14   70    金        1       カレイ野菜あんかけ  360.0           NaN
# 35    2014-1-17   85    金        1             回鍋肉  430.0           NaN
# 101   2014-4-23   63    水        0         手作りひれかつ  340.0           NaN
# 144   2014-6-26   49    木        0       キスと野菜の天ぷら  414.0           NaN
# 9    2013-11-29  116    金        0   タルタルinソーセージカツ    NaN           NaN
# 18   2013-12-12  109    木        0            肉じゃが    NaN           NaN
# 77    2014-3-19   72    水        1    越冬キャベツのメンチカツ  392.0           NaN
# 31    2014-1-10   87    金        0        手作りロースカツ  440.0           NaN
# 133   2014-6-11   50    水        1           チャプチェ  413.0           NaN
# 110    2014-5-9   58    金        1        手作りチキンカツ  434.0           NaN
# 114   2014-5-15   58    木        1        タンドリーチキン  403.0           NaN
# 69     2014-3-7   73    金        1        ボローニャ風カツ  396.0           NaN
# 2    2013-11-20  118    水        0      白身魚唐揚げ野菜あん    NaN           NaN
# 201   2014-9-22   29    月        0             筑前煮  395.0           NaN
# 19   2013-12-13  111    金        1        タンドリーチキン    NaN           NaN
# ..          ...  ...  ...      ...             ...    ...           ...
# 30     2014-1-9  129    木        1          鶏チリソース  435.0           NaN
# 89     2014-4-7  107    月        0         青梗菜牛肉炒め  387.0           NaN
# 130    2014-6-6   93    金        0        手作りロースカツ  430.0           NaN
# 11    2013-12-3  153    火        1        厚揚げ豚生姜炒め    NaN           NaN
# 28     2014-1-7  131    火        0    カレー入りソーセージカツ  404.0           NaN
# 99    2014-4-21  109    月        0            牛肉筍煮  375.0           NaN
# 16   2013-12-10  155    火        0   やわらかロースのサムジョン    NaN           NaN
# 48     2014-2-5  126    水        1         鶏のピリ辛焼き  420.0           NaN
# 118   2014-5-21  104    水        1        チーズハンバーグ  430.0           NaN
# 33    2014-1-15  134    水        0          さんま辛味焼  450.0           NaN
# 17   2013-12-11  157    水        0            五目御飯    NaN           NaN
# 60    2014-2-24  129    月        1          ポークハヤシ  408.0           NaN
# 20   2013-12-16  160    月        0       カキフライタルタル    NaN           NaN
# 70    2014-3-10  123    月        0    海老クリーミ―クノーデル  385.0           NaN
# 15    2013-12-9  165    月        1      ハンバーグデミソース    NaN           NaN
# 75    2014-3-17  129    月        0     鶏の唐揚げおろしソース  382.0           NaN
# 51    2014-2-10  137    月        0     鶏の唐揚げおろしソース  423.0           NaN
# 55    2014-2-17  137    月        1        チンジャオロース  416.0           NaN
# 65     2014-3-3  131    月        0     ハンバーグカレーソース  407.0           NaN
# 46     2014-2-3  139    月        1     ハンバーグカレーソース  445.0           NaN
# 85     2014-4-1  125    火        1           メンチカツ  377.0           NaN
# 13    2013-12-5  171    木        0     鶏のカッシュナッツ炒め    NaN           NaN
# 125   2014-5-30  119    金        0          チキンカレー    NaN      お楽しみメニュー
# 93    2014-4-11  128    金        1          チキンカレー    NaN      お楽しみメニュー
# 181   2014-8-22  100    金        1           ロコモコ丼    NaN      お楽しみメニュー
# 115   2014-5-16  126    金        0          ポークカレー    NaN      お楽しみメニュー
# 135   2014-6-13  121    金        0          キーマカレー    NaN      お楽しみメニュー
# 155   2014-7-11  124    金        0          ポークカレー    NaN      お楽しみメニュー
# 196   2014-9-12  115    金        0          ポークカレー    NaN      お楽しみメニュー
# 174    2014-8-8  129    金        0          チキンカレー    NaN      お楽しみメニュー
#
#              event  payday weather precipitation  temperature  year  month  \
# 27             NaN     NaN       曇            --          7.3  2013     12
# 0              NaN     NaN      快晴            --         19.8  2013     11
# 81             NaN     NaN       曇            --         18.7  2014      3
# 82             NaN     NaN       曇           1.5         12.4  2014      3
# 1              NaN     NaN      快晴            --         17.0  2013     11
# 104            NaN     NaN      晴れ            --         22.7  2014      4
# 64             NaN     NaN      晴れ            --         17.7  2014      2
# 107            NaN     NaN      晴れ            --         23.3  2014      5
# 102            NaN     NaN      晴れ            --         19.9  2014      4
# 98            ママの会     NaN       曇             0         11.4  2014      4
# 96             NaN     NaN      薄曇            --         21.5  2014      4
# 97             NaN     NaN      快晴            --         20.1  2014      4
# 72             NaN     NaN      快晴            --         14.8  2014      3
# 119            NaN     NaN      雷電             0         19.0  2014      5
# 128            NaN     NaN      晴れ            --         27.5  2014      6
# 74            ママの会     NaN       曇            --         11.5  2014      3
# 35            ママの会     NaN      快晴            --          7.8  2014      1
# 101            NaN     NaN      快晴            --         19.4  2014      4
# 144            NaN     NaN       曇            --         25.2  2014      6
# 9              NaN     NaN      快晴            --         12.1  2013     11
# 18             NaN     NaN      快晴            --         12.3  2013     12
# 77             NaN     NaN       曇            --         12.6  2014      3
# 31             NaN     1.0      快晴            --          5.1  2014      1
# 133            NaN     NaN       雨           2.5         22.3  2014      6
# 110            NaN     1.0      晴れ            --         23.4  2014      5
# 114            NaN     NaN       曇            --         19.3  2014      5
# 69             NaN     NaN      快晴            --          7.0  2014      3
# 2              NaN     NaN      快晴            --         15.5  2013     11
# 201            NaN     NaN      晴れ            --         25.2  2014      9
# 19             NaN     NaN      快晴            --         13.9  2013     12
# ..             ...     ...     ...           ...          ...   ...    ...
# 30             NaN     NaN       曇            --         10.9  2014      1
# 89             NaN     NaN      快晴            --         13.8  2014      4
# 130            NaN     NaN       雨           6.5         19.9  2014      6
# 11             NaN     NaN      快晴            --         13.9  2013     12
# 28             NaN     NaN      快晴            --          7.3  2014      1
# 99   キャリアアップ支援セミナー     NaN       曇            --         16.4  2014      4
# 16             NaN     1.0       曇           0.5          7.1  2013     12
# 48             NaN     NaN      快晴            --          3.0  2014      2
# 118            NaN     NaN       雨             6         17.4  2014      5
# 33             NaN     NaN       曇            --          2.9  2014      1
# 17             NaN     NaN       曇            --         11.0  2013     12
# 60             NaN     NaN       曇            --          6.6  2014      2
# 20             NaN     NaN      快晴            --         11.3  2013     12
# 70             NaN     1.0       曇            --          7.6  2014      3
# 15             NaN     NaN       曇            --          9.1  2013     12
# 75             NaN     NaN      快晴            --         14.0  2014      3
# 51             NaN     1.0       曇            --          7.8  2014      2
# 55             NaN     NaN      晴れ            --         11.6  2014      2
# 65             NaN     NaN       曇            --          7.8  2014      3
# 46             NaN     NaN      晴れ            --         15.9  2014      2
# 85             NaN     NaN      薄曇            --         16.1  2014      4
# 13             NaN     NaN      快晴            --         13.8  2013     12
# 125            NaN     NaN      薄曇            --         26.9  2014      5
# 93             NaN     NaN      快晴            --         16.5  2014      4
# 181            NaN     NaN      晴れ            --         33.1  2014      8
# 115           ママの会     NaN      快晴            --         23.8  2014      5
# 135            NaN     NaN      晴れ            --         29.5  2014      6
# 155            NaN     NaN      晴れ            --         33.9  2014      7
# 196            NaN     NaN      晴れ            --         27.3  2014      9
# 174            NaN     1.0       曇            --         31.1  2014      8
#
#            pred        res
# 27   131.674984 -51.674984
# 0    139.085028 -49.085028
# 81    94.354672 -43.354672
# 82    94.354672 -39.354672
# 1    139.085028 -38.085028
# 104   86.944628 -32.944628
# 64   101.764716 -32.764716
# 107   79.534583 -32.534583
# 102   86.944628 -30.944628
# 98    86.944628 -30.944628
# 96    86.944628 -29.944628
# 97    86.944628 -29.944628
# 72    94.354672 -26.354672
# 119   79.534583 -25.534583
# 128   72.124539 -25.124539
# 74    94.354672 -24.354672
# 35   109.174760 -24.174760
# 101   86.944628 -23.944628
# 144   72.124539 -23.124539
# 9    139.085028 -23.085028
# 18   131.674984 -22.674984
# 77    94.354672 -22.354672
# 31   109.174760 -22.174760
# 133   72.124539 -22.124539
# 110   79.534583 -21.534583
# 114   79.534583 -21.534583
# 69    94.354672 -21.354672
# 2    139.085028 -21.085028
# 201   49.894406 -20.894406
# 19   131.674984 -20.674984
# ..          ...        ...
# 30   109.174760  19.825240
# 89    86.944628  20.055372
# 130   72.124539  20.875461
# 11   131.674984  21.325016
# 28   109.174760  21.825240
# 99    86.944628  22.055372
# 16   131.674984  23.325016
# 48   101.764716  24.235284
# 118   79.534583  24.465417
# 33   109.174760  24.825240
# 17   131.674984  25.325016
# 60   101.764716  27.235284
# 20   131.674984  28.325016
# 70    94.354672  28.645328
# 15   131.674984  33.325016
# 75    94.354672  34.645328
# 51   101.764716  35.235284
# 55   101.764716  35.235284
# 65    94.354672  36.645328
# 46   101.764716  37.235284
# 85    86.944628  38.055372
# 13   131.674984  39.325016
# 125   79.534583  39.465417
# 93    86.944628  41.055372
# 181   57.304450  42.695550
# 115   79.534583  46.465417
# 135   72.124539  48.875461
# 155   64.714495  59.285505
# 196   49.894406  65.105594
# 174   57.304450  71.695550
#
# [207 rows x 16 columns]

# %% [markdown]
# ## 値が「お楽しみメニュー」であれば１、そうでなければ0とする自作関数を作りましょう
# - 自作の関数を作る為には、defを使います

# %%
def jisaku1(x):
    if x == "お楽しみメニュー":
        return 1
    else:
        return 0

# %% [markdown]
# ## jisaku1関数とapply関数を使って、trainとtestの新たなカラムfunを作りましょう

# %%
train["fun"] = train["remarks"].apply(lambda x : jisaku1(x))
test["fun"] = test["remarks"].apply(lambda x : jisaku1(x))

# %% [markdown]
# ## trainの中身を確認してみましょう

# %%
train
# Out:
#        datetime    y week  soldout            name   kcal          remarks  \
# 0    2013-11-18   90    月        0        厚切りイカフライ    NaN              NaN
# 1    2013-11-19  101    火        1         手作りヒレカツ    NaN              NaN
# 2    2013-11-20  118    水        0      白身魚唐揚げ野菜あん    NaN              NaN
# 3    2013-11-21  120    木        1          若鶏ピリ辛焼    NaN              NaN
# 4    2013-11-22  130    金        1        ビッグメンチカツ    NaN              NaN
# 5    2013-11-25  135    月        1            鶏の唐揚    NaN              NaN
# 6    2013-11-26  145    火        0        豚のスタミナ炒め    NaN              NaN
# 7    2013-11-27  140    水        1        ボローニャ風カツ    NaN              NaN
# 8    2013-11-28  151    木        0           ハンバーグ    NaN              NaN
# 9    2013-11-29  116    金        0   タルタルinソーセージカツ    NaN              NaN
# 10    2013-12-2  151    月        1           マーボ豆腐    NaN              NaN
# 11    2013-12-3  153    火        1        厚揚げ豚生姜炒め    NaN              NaN
# 12    2013-12-4  151    水        1    クリームチーズ入りメンチ    NaN              NaN
# 13    2013-12-5  171    木        0     鶏のカッシュナッツ炒め    NaN              NaN
# 14    2013-12-6  134    金        0        手作りロースカツ    NaN              NaN
# 15    2013-12-9  165    月        1      ハンバーグデミソース    NaN              NaN
# 16   2013-12-10  155    火        0   やわらかロースのサムジョン    NaN              NaN
# 17   2013-12-11  157    水        0            五目御飯    NaN              NaN
# 18   2013-12-12  109    木        0            肉じゃが    NaN              NaN
# 19   2013-12-13  111    金        1        タンドリーチキン    NaN              NaN
# 20   2013-12-16  160    月        0       カキフライタルタル    NaN              NaN
# 21   2013-12-17  145    火        0         手作りヒレカツ    NaN              NaN
# 22   2013-12-18  145    水        1             回鍋肉    NaN              NaN
# 23   2013-12-19  151    木        0         ポーク味噌焼き    NaN              NaN
# 24   2013-12-20  134    金        1       鶏の唐揚げ甘酢あん    NaN              NaN
# 25   2013-12-24  122    火        0       さっくりメンチカツ    NaN              NaN
# 26   2013-12-25  121    水        1       手ごね風ハンバーグ    NaN              NaN
# 27   2013-12-26   80    木        0              酢豚    NaN              NaN
# 28     2014-1-7  131    火        0    カレー入りソーセージカツ  404.0              NaN
# 29     2014-1-8  128    水        0          豚肉の生姜焼  462.0              NaN
# ..          ...  ...  ...      ...             ...    ...              ...
# 177   2014-8-18   56    月        0     洋食屋さんのメンチカツ  396.0              NaN
# 178   2014-8-19   53    火        1           牛スキヤキ  385.0              NaN
# 179   2014-8-20   56    水        0   豚ロースのピザ風チーズ焼き  423.0     料理長のこだわりメニュー
# 180   2014-8-21   54    木        0           チキン南蛮  405.0              NaN
# 181   2014-8-22  100    金        1           ロコモコ丼    NaN         お楽しみメニュー
# 182   2014-8-25   55    月        0        白身魚の南部焼き  412.0              NaN
# 183   2014-8-26   68    火        0          キーマカレー  400.0              NaN
# 184   2014-8-27   62    水        0         カレイの唐揚げ  410.0              NaN
# 185   2014-8-28   56    木        0        豚肉の胡麻シャブ  396.0              NaN
# 186   2014-8-29   39    金        0       チキンの辛味噌焼き  398.0              NaN
# 187    2014-9-1   65    月        1         ビーフシチュー  380.0              NaN
# 188    2014-9-2   68    火        1         名古屋味噌カツ  440.0            手作りの味
# 189    2014-9-3   53    水        0             親子煮  408.0              NaN
# 190    2014-9-4   54    木        1  チキンステーキ・きのこソース  405.0              NaN
# 191    2014-9-5   43    金        0           メンチカツ  380.0              NaN
# 192    2014-9-8   68    月        1         鶏肉の山賊焼き  385.0              NaN
# 193    2014-9-9   63    火        0      ハンバーグデミソース  460.0              NaN
# 194   2014-9-10   54    水        0     ぶりレモンペッパー焼き  450.0              NaN
# 195   2014-9-11   53    木        0        手作りチキンカツ  385.0              NaN
# 196   2014-9-12  115    金        0          ポークカレー    NaN         お楽しみメニュー
# 197   2014-9-16   56    火        0        チーズメンチカツ  438.0              NaN
# 198   2014-9-17   49    水        0        チキンフリカッセ  430.0     料理長のこだわりメニュー
# 199   2014-9-18   46    木        0     カレイ唐揚げ 甘酢あん  395.0              NaN
# 200   2014-9-19   45    金        0         厚切イカフライ  400.0              NaN
# 201   2014-9-22   29    月        0             筑前煮  395.0              NaN
# 202   2014-9-24   59    水        1     白身魚のマスタード焼き  408.0              NaN
# 203   2014-9-25   50    木        0         牛カルビ焼き肉  394.0              NaN
# 204   2014-9-26   45    金        0        ランチビュッフェ    NaN  スペシャルメニュー（800円）
# 205   2014-9-29   56    月        1        豚肉と玉子の炒め  404.0              NaN
# 206   2014-9-30   40    火        0    鶏肉とカシューナッツ炒め  398.0              NaN
#
#              event  payday weather precipitation  temperature  year  month  \
# 0              NaN     NaN      快晴            --         19.8  2013     11
# 1              NaN     NaN      快晴            --         17.0  2013     11
# 2              NaN     NaN      快晴            --         15.5  2013     11
# 3              NaN     NaN      快晴            --         15.2  2013     11
# 4              NaN     NaN      快晴            --         16.1  2013     11
# 5              NaN     NaN       曇            --         14.6  2013     11
# 6              NaN     NaN      快晴            --         17.9  2013     11
# 7              NaN     NaN      晴れ            --         14.7  2013     11
# 8              NaN     NaN      薄曇            --         17.7  2013     11
# 9              NaN     NaN      快晴            --         12.1  2013     11
# 10             NaN     NaN      快晴            --         13.8  2013     12
# 11             NaN     NaN      快晴            --         13.9  2013     12
# 12             NaN     NaN      晴れ            --         13.5  2013     12
# 13             NaN     NaN      快晴            --         13.8  2013     12
# 14             NaN     NaN      快晴            --         14.9  2013     12
# 15             NaN     NaN       曇            --          9.1  2013     12
# 16             NaN     1.0       曇           0.5          7.1  2013     12
# 17             NaN     NaN       曇            --         11.0  2013     12
# 18             NaN     NaN      快晴            --         12.3  2013     12
# 19             NaN     NaN      快晴            --         13.9  2013     12
# 20             NaN     NaN      快晴            --         11.3  2013     12
# 21            ママの会     NaN       曇            --         10.8  2013     12
# 22             NaN     NaN       曇            --          7.8  2013     12
# 23             NaN     NaN       雨           0.5          6.8  2013     12
# 24             NaN     NaN       曇            --          8.4  2013     12
# 25             NaN     NaN      快晴            --         11.5  2013     12
# 26             NaN     NaN      快晴            --          8.0  2013     12
# 27             NaN     NaN       曇            --          7.3  2013     12
# 28             NaN     NaN      快晴            --          7.3  2014      1
# 29             NaN     NaN       曇            --          9.8  2014      1
# ..             ...     ...     ...           ...          ...   ...    ...
# 177            NaN     NaN       曇            --         32.2  2014      8
# 178            NaN     NaN      晴れ            --         33.3  2014      8
# 179           ママの会     NaN      快晴            --         33.3  2014      8
# 180  キャリアアップ支援セミナー     NaN      薄曇            --         33.0  2014      8
# 181            NaN     NaN      晴れ            --         33.1  2014      8
# 182            NaN     NaN       曇             0         26.0  2014      8
# 183            NaN     NaN       雨             0         26.2  2014      8
# 184            NaN     NaN       曇             0         21.0  2014      8
# 185            NaN     NaN       雨             0         21.6  2014      8
# 186            NaN     NaN       曇             0         25.1  2014      8
# 187            NaN     NaN       曇            --         23.4  2014      9
# 188            NaN     NaN      晴れ            --         29.1  2014      9
# 189            NaN     NaN       曇            --         26.7  2014      9
# 190            NaN     NaN       曇             0         26.5  2014      9
# 191            NaN     NaN      晴れ            --         30.2  2014      9
# 192            NaN     NaN       曇            --         23.1  2014      9
# 193            NaN     NaN      晴れ            --         26.8  2014      9
# 194            NaN     1.0       曇             0         25.0  2014      9
# 195            NaN     NaN       曇            --         21.9  2014      9
# 196            NaN     NaN      晴れ            --         27.3  2014      9
# 197            NaN     NaN      晴れ            --         28.8  2014      9
# 198           ママの会     NaN       曇            --         25.0  2014      9
# 199            NaN     NaN       曇            --         24.1  2014      9
# 200            NaN     NaN      薄曇            --         23.6  2014      9
# 201            NaN     NaN      晴れ            --         25.2  2014      9
# 202            NaN     NaN       曇             0         24.8  2014      9
# 203            NaN     NaN       曇             0         25.4  2014      9
# 204  キャリアアップ支援セミナー     NaN      晴れ            --         27.1  2014      9
# 205            NaN     NaN      快晴            --         26.6  2014      9
# 206            NaN     NaN      快晴            --         28.1  2014      9
#
#            pred        res  fun
# 0    139.085028 -49.085028    0
# 1    139.085028 -38.085028    0
# 2    139.085028 -21.085028    0
# 3    139.085028 -19.085028    0
# 4    139.085028  -9.085028    0
# 5    139.085028  -4.085028    0
# 6    139.085028   5.914972    0
# 7    139.085028   0.914972    0
# 8    139.085028  11.914972    0
# 9    139.085028 -23.085028    0
# 10   131.674984  19.325016    0
# 11   131.674984  21.325016    0
# 12   131.674984  19.325016    0
# 13   131.674984  39.325016    0
# 14   131.674984   2.325016    0
# 15   131.674984  33.325016    0
# 16   131.674984  23.325016    0
# 17   131.674984  25.325016    0
# 18   131.674984 -22.674984    0
# 19   131.674984 -20.674984    0
# 20   131.674984  28.325016    0
# 21   131.674984  13.325016    0
# 22   131.674984  13.325016    0
# 23   131.674984  19.325016    0
# 24   131.674984   2.325016    0
# 25   131.674984  -9.674984    0
# 26   131.674984 -10.674984    0
# 27   131.674984 -51.674984    0
# 28   109.174760  21.825240    0
# 29   109.174760  18.825240    0
# ..          ...        ...  ...
# 177   57.304450  -1.304450    0
# 178   57.304450  -4.304450    0
# 179   57.304450  -1.304450    0
# 180   57.304450  -3.304450    0
# 181   57.304450  42.695550    1
# 182   57.304450  -2.304450    0
# 183   57.304450  10.695550    0
# 184   57.304450   4.695550    0
# 185   57.304450  -1.304450    0
# 186   57.304450 -18.304450    0
# 187   49.894406  15.105594    0
# 188   49.894406  18.105594    0
# 189   49.894406   3.105594    0
# 190   49.894406   4.105594    0
# 191   49.894406  -6.894406    0
# 192   49.894406  18.105594    0
# 193   49.894406  13.105594    0
# 194   49.894406   4.105594    0
# 195   49.894406   3.105594    0
# 196   49.894406  65.105594    1
# 197   49.894406   6.105594    0
# 198   49.894406  -0.894406    0
# 199   49.894406  -3.894406    0
# 200   49.894406  -4.894406    0
# 201   49.894406 -20.894406    0
# 202   49.894406   9.105594    0
# 203   49.894406   0.105594    0
# 204   49.894406  -4.894406    0
# 205   49.894406   6.105594    0
# 206   49.894406  -9.894406    0
#
# [207 rows x 17 columns]

# %% [markdown]
# ## train,testからyearとmonth、funとtemperatureの4カラムを取り出し、変数trainX,testXに代入しましょう

# %%
trainX = train[["year", "month", "fun", "temperature"]]
testX = test[["year", "month", "fun", "temperature"]]

# %% [markdown]
# ## 回帰モデルの箱を用意しましょう
# - 変数名はmodel2としましょう

# %%
model2 = LR()

# %% [markdown]
# ## 重回帰モデルを作りましょう

# %%
model2.fit(trainX, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %% [markdown]
# ## 作ったモデルの傾きや切片を確かめてみましょう

# %%
model2.coef_
# Out:
# array([-76.3765687 ,  -4.20489757,  44.63348171,  -1.25463854])

# %%
model2.intercept_
# Out:
# 153945.25411758339

# %% [markdown]
# ## testXを使って予測をし、予測結果を変数pred2に代入しましょう

# %%
pred2 = model2.predict(testX)

# %% [markdown]
# ## sample[1]に予測結果を代入しましょう

# %%
sample[1] = pred2

# %% [markdown]
# ## sampleを"submit5.csv"というファイルで出力して、DeepAnalyticsに投稿しましょう

# %%
sample.to_csv("submit5.csv", index=None, header=None)
